# %%
# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# Visualización
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Evaluar linealidad de las relaciones entre las variables
# ------------------------------------------------------------------------------
from scipy.stats import shapiro, kstest

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# Gestión de los warnings
# -----------------------------------------------------------------------
import warnings
warnings.filterwarnings("ignore")

# %%
df_episodio = pd.read_csv("datasets_friends/friends_quotes.csv", index_col=0) 

df_episodio
# Out:
#           episode_number              episode_title  \
# author
# Monica               1.0     Monica Gets A Roommate
# Joey                 1.0     Monica Gets A Roommate
# Chandler             1.0     Monica Gets A Roommate
# Phoebe               1.0     Monica Gets A Roommate
# Phoebe               1.0     Monica Gets A Roommate
# ...                  ...                        ...
# Chandler            17.0  The Last One, Part I & II
# Rachel              17.0  The Last One, Part I & II
# Monica              17.0  The Last One, Part I & II
# Rachel              17.0  The Last One, Part I & II
# Chandler            17.0  The Last One, Part I & II
#
#                                                       quote  quote_order  \
# author
# Monica    There's nothing to tell! He's just some guy I ...          0.0
# Joey      C'mon, you're going out with the guy! There's ...          1.0
# Chandler  All right Joey, be nice. So does he have a hum...          2.0
# Phoebe                             Wait, does he eat chalk?          3.0
# Phoebe    Just, 'cause, I don't want her to go through w...          4.0
# ...                                                     ...          ...
# Chandler                            Oh, it's gonna be okay.        581.0
# Rachel    (crying) Do you guys have to go to the new hou...        582.0
# Monica                                    We got some time.        583.0
# Rachel                     Okay, should we get some coffee?        584.0
# Chandler                                       Sure. Where?        585.0
#
#           season
# author
# Monica       1.0
# Joey         1.0
# Chandler     1.0
# Phoebe       1.0
# Phoebe       1.0
# ...          ...
# Chandler    10.0
# Rachel      10.0
# Monica      10.0
# Rachel      10.0
# Chandler    10.0
#
# [60291 rows x 5 columns]
